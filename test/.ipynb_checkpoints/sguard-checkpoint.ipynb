# %%
import numpy as np
import pandas as pd
import requests as req
import time
import re
import glob
import os
import subprocess
from bs4 import BeautifulSoup

# %% [markdown]
# # 1. Load smart contract addresses from contract-library.com

# %%
### Download Smart Contract Meta Data
if False:
    MAX_PAGE = 1000
    AT_PAGE = 0
    contracts = {"address": [], "block_number": [], "ether": [], "has_source": [] }
    base_url = "https://contract-library.com/api/contracts?"
    for idx in range(MAX_PAGE - AT_PAGE):
        ### Start Downloading
        page_number = idx + 1 + AT_PAGE
        end_point = "{0}n=Ethereum&q=&t=address&s=block_number&o=desc&p={1}&c=100&w=".format(base_url, page_number)
        r = req.get(end_point)
        assert(r.status_code == 200)
        print("=> page_number: {}".format(page_number))
        json = r.json()
        for contract in json["contracts"]:
            contracts["address"].append(contract["address"])
            contracts["block_number"].append(contract["block_number"])
            contracts["ether"].append(contract["ether"])
            contracts["has_source"].append(contract["has_source"])
        ## Write Fragment
        if page_number % 100 == 0:
            csv_file = "assets/addr_{}.csv".format(int(page_number / 100))
            df = pd.DataFrame(contracts)
            df.to_csv(csv_file, header=None, index=False)
            print("=> write to {}".format(csv_file))
            print("=> sleep 2 seconds")
            time.sleep(2)
            ### Clear Contract Data
            contracts["address"] = []
            contracts["block_number"] = []
            contracts["ether"] = []
            contracts["has_source"] = []

# %% [markdown]
# # 2. Supported version by symEvm

# %%
## Supported compiler versions
if False:
    versions = []
    for i in range(25 - 18 + 1):
        versions.append("0.4.{}".format(i + 18))
    for i in range(16 - 0 + 1):
        versions.append("0.5.{}".format(i))
    for i in range(3 + 1):
        versions.append("0.6.{}".format(i))
    print("=> supported version: {}".format(len(versions)))

# %% [markdown]
# # 3. Download source code from etherscan

# %%
### Filter contract source code by version
if False:
    df = pd.read_csv(
        "assets/addr.csv",
        header=None,
        names=["address", "block_number", "ether", "has_source"],
    )
    df_with_source = df[(df.has_source == True)]
    print(df_with_source.describe())
    for address in df_with_source["address"]:
        end_point = "https://etherscan.io/address/{}#code".format(address)
        r = req.get(end_point, headers={"user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.113 Safari/537.36"})
        assert(r.status_code == 200)
        print("=> address: {}".format(address))
        soup = BeautifulSoup(r.text, 'html.parser')
        editor = soup.find(id="editor")
        match = re.findall(r"pragma(\s+)solidity(\s+)[^\d]*((\d+\.?)+)", editor.text)
        print(match)
        if len(match) > 0 and len(match[0]) > 2:
            version = match[0][2]
            if version in versions:
                with open("contracts/{}_{}".format(address, version), "w") as f:
                    f.write(editor.text)

# %% [markdown]
# # 4. Filter smart contracts by source code and version

# %%
### Report 1
if False:
    num_addr = !cat assets/addr.csv | wc -l
    num_addr = int(num_addr[0])
    files = !find contracts/ -type f -not -name "*.csv" -not -name "*.json"
    print("=> contracts {}".format(num_addr))
    print("=> sup_contracts {}".format(len(files)))
    print("=> % {}".format(len(files) / num_addr * 100))

# %% [markdown]
# # 5. Use local compiler to filter smart contracts

# %%
### Filter smart contract if it can not be compiled 
if False:
    files = !find contracts/ -not -name "*.csv" -not -name "*.json"
    error_files = []
    for idx, file in enumerate(files):
        version = file.split('_')[1]
        os.environ["SYM_SOLC_VERSION"] = version
        os.environ["SYM_FILE"] = file
        # !solc use "$SYM_SOLC_VERSION" > /dev/null 2>&1
        output = !solc $SYM_FILE
        if "Error" in ",".join(output):
            print("=> FAIL {}".format(file))
            error_files.append(file)
        else:
            print("=> OK {}".format(file))
    df = pd.DataFrame(error_files)
    csv_file = "contracts/errors.csv"
    df.to_csv(csv_file, header=None, index=False)

# %% [markdown]
# # 6. Show executable smart contracts

# %%
### Report 2
if False:
    files = !find contracts/ -type f -not -name "*.csv" -not -name "*.json"
    num_errors = !cat contracts/errors.csv | wc -l
    num_errors = int(num_errors[0])
    print("=> sup_contracts: {}".format(len(files)))
    print("=> error: {}".format(num_errors))
    print("=> comp : {}".format(len(files) - num_errors))
    print("=> % {}".format((len(files) - num_errors)/len(files) * 100))

# %% [markdown]
# # 7. Use local compiler to compile smart contracts

# %%
if False:
    files = !find contracts/ -type f -not -name "*.csv" -not -name "*.json"
    df = pd.read_csv("contracts/errors.csv", header=None, names=["contract_path"])
    for contract_path in df["contract_path"]:
        if contract_path in files:
            files.remove(contract_path)
    print("=> comp: {}".format(len(files)))
    compiled_files = []
    for idx, file in enumerate(files):
        version = file.split('_')[1]
        os.environ["SYM_SOLC_VERSION"] = version
        os.environ["SYM_FILE"] = file
        os.environ["SYM_FILE_OUTPUT"] = "{}.json".format(file)
        print("=> {} / {} {}".format(idx + 1, len(files), file))
        # !solc use $SYM_SOLC_VERSION > /dev/null 2>&1
        # !solc --combined-json bin-runtime,srcmap-runtime,ast,asm $SYM_FILE > $SYM_FILE_OUTPUT
        compiled_files.append(file)
    df = pd.DataFrame(compiled_files)
    csv_file = "contracts/compiled.csv"
    df.to_csv(csv_file, header=None, index=False)

# %% [markdown]
# # 8. Show smart contract list

# %%
### Report 3
if True:
    df = pd.read_csv("contracts/compiled.csv", header=None, names=["contract_path"])
    num_ok = 0
    for contract_path in df["contract_path"]:
        with open(contract_path + ".json", "r") as f:
            if len(f.read()) == 0:
                continue
            num_ok = num_ok + 1
    print("=> num_ok: " + str(num_ok))
# Out:
# => num_ok: 1749

# %% [markdown]
# # 9. Set configuration for SymEVM

# %%
env_content = """
dataload=02
expectCoverage=0.95
maxVisitedBlock=30
maxVisitedBlockBound=100
maxVisitedBlockStep=10
allocatedRange="a0"
""".strip()
with open(".env", "w") as f:
    f.write(env_content)

# %% [markdown]
# # 10. Execute smart contract by SymEVM

# %%
### Run symEvm for coverage
if True:
    exceptions = {
        "address": [],
        "heap": [],
        "timeout": [],
        "others": [],
    }
    result = {
        # Concolic 
        "address": [], 
        "contract_name": [],
        "endpoints": [], 
        "covered_jumpis": [], 
        "total_jumpis": [],
        "bytelen": [],
        # Tainting analysis
        "success_sloads": [],
        "success_mloads": [],
        "success_mstores": [],
        "success_sstores": [],
        "failed_sloads": [],
        "failed_mloads": [],
        "failed_mstores": [],
        "failed_sstores": [],
        # Scanner
        "address": [],
        "integer": [],
        "disorder": [],
        "frez": [],
        "reentrancy": [],
        "delegate": [],
        "number": [],
        "timestamp": [],
        # Duration
        "concolic_duration": [],
        "tainting_duration": [],
        "scanner_duration": [],
    }
    df = pd.read_csv("contracts/compiled.csv", header=None, names=["contract_path"])
    files = ["results/sym_evm.csv", "results/exception.csv"]
    for file in files:
        if os.path.exists(file):
             os.remove(file)
        with open(file, "w") as f:
            pass
    contract_paths = df["contract_path"]
    for idx, contract_path in enumerate(contract_paths):
        os.environ["SYM_CONTRACT_FILE"] = contract_path
        os.environ["SYM_JSON_FILE"] = "{}.json".format(contract_path)
        print("{} / {} - {}".format(idx + 1, len(contract_paths), contract_path))
        ## if json file is empty
        with open(contract_path + ".json", "r") as f:
            if len(f.read()) == 0:
                continue
        ## execute SymEvm
        addr = contract_path.split('/')[2].split('_')[0]
        output = !timeout 120 node index.js
        output = '\n'.join(output)
        print(output)
        ## contract
        heap_error = "heap out of memory" in output
        has_error = "error" in output
        is_ok = !has_error
        if is_ok:
            #--------------------------------#
            #           Concolic
            #--------------------------------#
            if True:
                match = re.findall(r"Start Analyzing Contract:\s+([^\n]+)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:   
                    contract_name = match[0]
                ## endpoints
                match = re.findall(r"endpoints\s+:\s+(\d+)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:
                    endpoints = int(match[0])
                ## cjumpis
                match = re.findall(r"cjumpis\s+:\s+(\d+)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:
                    cjumpis = int(match[0])
                ## njumpis
                match = re.findall(r"njumpis\s+:\s+(\d+)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:
                    njumpis = int(match[0])
                ## byte len
                match = re.findall(r"bytelen\s+:\s+(\d+)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:
                    bytelen = int(match[0])
                ## concolic duration
                match = re.findall(r"concolic\s+:\s+(\d+)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:
                    concolic_duration = int(match[0])
            #--------------------------------#
            #           Tainting
            #--------------------------------#
            if True:
                ## success
                match = re.findall(r"success\s+:\s+\[([^\]]+)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:
                    success = list(map(lambda x: int(x), match[0].split(',')))
                ## failed
                match = re.findall(r"failed\s+:\s+\[([^\]]+)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:
                    failed = list(map(lambda x: int(x), match[0].split(',')))
                ## tainting duration
                match = re.findall(r"tainting\s+:\s+(\d+)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:
                    tainting_duration = int(match[0])
            #--------------------------------#
            #           Scanner
            #--------------------------------#
            if True:
                ## integer
                match = re.findall(r"integer\s+:\s+(false|true)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:
                    integer = 0 if match[0] == 'false' else 1
                ## disorder
                match = re.findall(r"disorder\s+:\s+(false|true)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:
                    disorder = 0 if match[0] == 'false' else 1
                ## frez
                match = re.findall(r"frez\s+:\s+(false|true)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:
                    frez = 0 if match[0] == 'false' else 1
                ## reentrancy
                match = re.findall(r"reentrancy\s+:\s+(false|true)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:
                    reentrancy = 0 if match[0] == 'false' else 1
                ## number
                match = re.findall(r"number\s+:\s+(false|true)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:
                    number = 0 if match[0] == 'false' else 1
                ## timestamp
                match = re.findall(r"timestamp\s+:\s+(false|true)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:
                    timestamp = 0 if match[0] == 'false' else 1
                ## delegate
                match = re.findall(r"delegate\s+:\s+(false|true)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:
                    delegate = 0 if match[0] == 'false' else 1
                ## tainting duration
                match = re.findall(r"scanner\s+:\s+(\d+)", output)
                is_ok = is_ok and len(match) > 0
                if is_ok:
                    scanner_duration = int(match[0])
        if is_ok:
            ## Concolic
            result["address"].append(addr)
            result["endpoints"].append(endpoints)
            result["covered_jumpis"].append(cjumpis)
            result["total_jumpis"].append(njumpis)
            result["contract_name"].append(contract_name)
            result["bytelen"].append(bytelen)
            result["concolic_duration"].append(concolic_duration)
            ## Tainting
            result["success_sloads"].append(success[0])
            result["success_mloads"].append(success[1])
            result["success_mstores"].append(success[2])
            result["success_sstores"].append(success[3])
            result["failed_sloads"].append(failed[0])
            result["failed_mloads"].append(failed[1])
            result["failed_mstores"].append(failed[2])
            result["failed_sstores"].append(failed[3])
            result["tainting_duration"].append(tainting_duration)
            ## Scanner
            result["integer"].append(integer)
            result["disorder"].append(disorder)
            result["frez"].append(frez)
            result["reentrancy"].append(reentrancy)
            result["number"].append(number)
            result["timestamp"].append(timestamp)
            result["delegate"].append(delegate)
            result["scanner_duration"].append(scanner_duration)
        else:
            exceptions["address"].append(addr)
            if heap_error:
                exceptions["heap"].append(1)
                exceptions["others"].append(0)
                exceptions["timeout"].append(0)
            elif has_error:
                exceptions["others"].append(1)
                exceptions["heap"].append(0)
                exceptions["timeout"].append(0)
            else:
                exceptions["timeout"].append(1)
                exceptions["others"].append(0)
                exceptions["heap"].append(0)
    df = pd.DataFrame(result)
    df.to_csv(files[0], index=None)
    df = pd.DataFrame(exceptions)
    df.to_csv(files[1], index=None)
# Out:
# 1 / 1981 - contracts//0x37a4860728e292e5852b215c46dbe7a18862ef93_0.5.16
# [symEvm] info: Start Analyzing Contract: BCHGateway
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 130
# [symEvm] info: |	cjumpis    : 46
# [symEvm] info: |	njumpis    : 46
# [symEvm] info: |	bytelen    : 3278
# [symEvm] info: |	concolic   : 34
# [symEvm] info: |	success    : [193,1161,1049,78]
# [symEvm] info: |	failed     : [0,0,0,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 1640
# [symEvm] info: |	scanner    : 19402
# [symEvm] info: |	integer    : true
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : false
# [symEvm] info: |	reentrancy : true
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : true
# 2 / 1981 - contracts//0x01e1bd903f14c06a5f6fd85a677c33731b3afe9e_0.4.18
# [symEvm] info: Start Analyzing Contract: ConversionRates
# [symEvm] info: update maxVisitedBlock to 40
# [symEvm] info: update maxVisitedBlock to 50
# [symEvm] info: update maxVisitedBlock to 60
# 3 / 1981 - contracts//0x522696c2004b1864da316122c1c54a06e21197b6_0.4.24
# [symEvm] info: Start Analyzing Contract: ERC20
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 1099
# [symEvm] info: |	cjumpis    : 41
# [symEvm] info: |	njumpis    : 41
# [symEvm] info: |	bytelen    : 4363
# [symEvm] info: |	concolic   : 199
# [symEvm] info: |	success    : [26210,26924,20797,14]
# [symEvm] info: |	failed     : [0,554,554,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 45845
# [symEvm] info: |	scanner    : 79
# [symEvm] info: |	integer    : false
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : false
# [symEvm] info: |	reentrancy : false
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : false
# 4 / 1981 - contracts//0xcd9c448b47711729b68f9766e7c49c23578e59d6_0.4.19
# [symEvm] info: Start Analyzing Contract: BFCToken
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 126
# [symEvm] info: |	cjumpis    : 29
# [symEvm] info: |	njumpis    : 29
# [symEvm] info: |	bytelen    : 2880
# [symEvm] info: |	concolic   : 27
# [symEvm] info: |	success    : [87,2671,1864,25]
# [symEvm] info: |	failed     : [0,48,48,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 3818
# [symEvm] info: |	scanner    : 51
# [symEvm] info: |	integer    : false
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : false
# [symEvm] info: |	reentrancy : false
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : false
# 5 / 1981 - contracts//0xb2fd963dbc22e56eec0826ebb9289f3959314a34_0.5.15
# [symEvm] info: Start Analyzing Contract: ERC20Token
# [symEvm] info: update maxVisitedBlock to 40
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 4690
# [symEvm] info: |	cjumpis    : 150
# [symEvm] info: |	njumpis    : 150
# [symEvm] info: |	bytelen    : 13771
# [symEvm] info: |	concolic   : 794
# 6 / 1981 - contracts//0xadcffd0f6d92139d99e10ed35559edfb1fb9c106_0.5.0
# [symEvm] info: Start Analyzing Contract: SmartexOracle
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 50
# [symEvm] info: |	cjumpis    : 44
# [symEvm] info: |	njumpis    : 46
# [symEvm] info: |	bytelen    : 3741
# [symEvm] info: |	concolic   : 18
# [symEvm] info: |	success    : [99,12,168,19]
# [symEvm] info: |	failed     : [0,0,0,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 148
# [symEvm] info: |	scanner    : 86
# [symEvm] info: |	integer    : false
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : false
# [symEvm] info: |	reentrancy : false
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : false
# 7 / 1981 - contracts//0xcf939c2cbc27cdaef59d215e1a89ed4c8cc3ac2d_0.4.24
# [symEvm] info: Start Analyzing Contract: ERC20Token
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 1086
# [symEvm] info: |	cjumpis    : 33
# [symEvm] info: |	njumpis    : 33
# [symEvm] info: |	bytelen    : 2882
# [symEvm] info: |	concolic   : 217
# [symEvm] info: |	success    : [26182,26877,20698,13]
# [symEvm] info: |	failed     : [0,554,554,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 46580
# [symEvm] info: |	scanner    : 56
# [symEvm] info: |	integer    : false
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : false
# [symEvm] info: |	reentrancy : false
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : false
# 8 / 1981 - contracts//0xb5371de91bde1dc3640219887ea03510a4a2701b_0.5.11
# [symEvm] info: Start Analyzing Contract: DharmaSmartWalletImplementationV8Staging
# [symEvm] info: update maxVisitedBlock to 40
# [symEvm] info: update maxVisitedBlock to 50
# [symEvm] info: update maxVisitedBlock to 60
# [symEvm] info: update maxVisitedBlock to 70
# [symEvm] info: update maxVisitedBlock to 80
# [symEvm] info: update maxVisitedBlock to 90
# [symEvm] info: update maxVisitedBlock to 100
#
# <--- Last few GCs --->
#
# [28913:0x1042d4000]    35292 ms: Scavenge 2038.2 (2042.2) -> 2037.6 (2042.7) MB, 3.4 / 0.0 ms  (average mu = 0.099, current mu = 0.091) allocation failure
# [28913:0x1042d4000]    35351 ms: Scavenge 2038.4 (2042.7) -> 2037.7 (2042.7) MB, 3.2 / 0.0 ms  (average mu = 0.099, current mu = 0.091) allocation failure
# [28913:0x1042d4000]    35414 ms: Scavenge 2038.5 (2042.7) -> 2038.0 (2042.7) MB, 3.3 / 0.0 ms  (average mu = 0.099, current mu = 0.091) allocation failure
#
#
# <--- JS stacktrace --->
#
# ==== JS stack trace =========================================
#
#     0: ExitFrame [pc: 0x100954639]
# Security context: 0x08e40f740921 <JSObject>
#     1: execute [0x8e4da0a2679] [/Users/wuco/Projects/symEvm/src/evm/evm.js:~60] [pc=0x2d0a4404cbc5](this=0x08e4abe00619 <Evm map = 0x8e4630be511>,34654,0x08e46d599c91 <Ep map = 0x8e4b407f001>)
#     2: execute [0x8e4da0a2679] [/Users/wuco/Projects/symEvm/src/evm/evm.js:~60] [pc=0x2d0a4404c7dd](this=0x08e4abe00619 <Evm map = 0x8e4630be511>,34627,0x08e41305b799 <Ep...
#
# FATAL ERROR: Ineffective mark-compacts near heap limit Allocation failed - JavaScript heap out of memory
#  1: 0x100082360 node::Abort() [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  2: 0x1000824e4 node::errors::TryCatchScope::~TryCatchScope() [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  3: 0x100182ba7 v8::Utils::ReportOOMFailure(v8::internal::Isolate*, char const*, bool) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  4: 0x100182b43 v8::internal::V8::FatalProcessOutOfMemory(v8::internal::Isolate*, char const*, bool) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  5: 0x10030afc5 v8::internal::Heap::FatalProcessOutOfMemory(char const*) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  6: 0x10030c6a4 v8::internal::Heap::RecomputeLimits(v8::internal::GarbageCollector) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  7: 0x10030943e v8::internal::Heap::PerformGarbageCollection(v8::internal::GarbageCollector, v8::GCCallbackFlags) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  8: 0x100307426 v8::internal::Heap::CollectGarbage(v8::internal::AllocationSpace, v8::internal::GarbageCollectionReason, v8::GCCallbackFlags) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  9: 0x1003062d1 v8::internal::Heap::HandleGCRequest() [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 10: 0x1002cae40 v8::internal::StackGuard::HandleInterrupts() [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 11: 0x100620a29 v8::internal::Runtime_StackGuard(int, unsigned long*, v8::internal::Isolate*) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 12: 0x100954639 Builtins_CEntry_Return1_DontSaveFPRegs_ArgvOnStack_NoBuiltinExit [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 9 / 1981 - contracts//0xe3a0ba3f82784b37545450a0cc0dd04b08e721e1_0.5.12
# [symEvm] info: Start Analyzing Contract: Date
# [symEvm] info: update maxVisitedBlock to 40
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 2680
# [symEvm] info: |	cjumpis    : 59
# [symEvm] info: |	njumpis    : 62
# [symEvm] info: |	bytelen    : 2273
# [symEvm] info: |	concolic   : 733
# [symEvm] info: |	success    : [0,39,5649,0]
# [symEvm] info: |	failed     : [0,0,0,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 4107
# [symEvm] info: |	scanner    : 198
# [symEvm] info: |	integer    : false
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : true
# [symEvm] info: |	reentrancy : false
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : false
# 10 / 1981 - contracts//0x0602121722642936150f12ea1e07d62a8bb2aa71_0.5.0
# [symEvm] info: Start Analyzing Contract: BOBT
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 1304
# [symEvm] info: |	cjumpis    : 52
# [symEvm] info: |	njumpis    : 52
# [symEvm] info: |	bytelen    : 5417
# [symEvm] info: |	concolic   : 202
# [symEvm] info: |	success    : [26541,31327,24861,79]
# [symEvm] info: |	failed     : [0,654,654,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 49018
# [symEvm] info: |	scanner    : 94
# [symEvm] info: |	integer    : false
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : false
# [symEvm] info: |	reentrancy : false
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : false
# 11 / 1981 - contracts//0x24177a6579f52ddcf85e085afeb95a8bbe5b715d_0.5.0
# 12 / 1981 - contracts//0x1c805cd11be4fc7ee60a2b6b490cb217caafa9bd_0.5.0
# [symEvm] info: Start Analyzing Contract: TokenDistributor
# [symEvm] info: update maxVisitedBlock to 40
#
# <--- Last few GCs --->
#
# [28924:0x1042d4000]    18035 ms: Scavenge 2046.4 (2050.1) -> 2046.2 (2050.8) MB, 4.3 / 0.0 ms  (average mu = 0.136, current mu = 0.036) allocation failure
# [28924:0x1042d4000]    18122 ms: Mark-sweep 2046.9 (2050.8) -> 2046.4 (2050.8) MB, 36.6 / 0.0 ms  (+ 895.0 ms in 196 steps since start of marking, biggest step 7.1 ms, walltime since start of marking 1004 ms) (average mu = 0.113, current mu = 0.087) alloc
#
# <--- JS stacktrace --->
#
# ==== JS stack trace =========================================
#
#     0: ExitFrame [pc: 0x100954639]
#     1: StubFrame [pc: 0x1008e1e1a]
# Security context: 0x101826a00921 <JSObject>
#     2: init [0x10181f099e29] [/Users/wuco/Projects/symEvm/node_modules/bn.js/lib/bn.js:~76] [pc=0x3b18ad4f022a](this=0x1018f0b13341 <BN map = 0x10180b9b3611>,0x1018f0b132e9 <String[4]: 017f>,16,0x101863b572a9 <String[#2]: be>)
#     3: execute [0x10189caf45e1] [/Users/wuco/Projects/symEvm/src/evm/evm.js:~60] [pc=0x3b18ad4cb9c4](...
#
# FATAL ERROR: Ineffective mark-compacts near heap limit Allocation failed - JavaScript heap out of memory
#
# Writing Node.js report to file: report.20200426.183032.28924.0.001.json
# Node.js report completed
#  1: 0x100082360 node::Abort() [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  2: 0x1000824e4 node::errors::TryCatchScope::~TryCatchScope() [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  3: 0x100182ba7 v8::Utils::ReportOOMFailure(v8::internal::Isolate*, char const*, bool) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  4: 0x100182b43 v8::internal::V8::FatalProcessOutOfMemory(v8::internal::Isolate*, char const*, bool) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  5: 0x10030afc5 v8::internal::Heap::FatalProcessOutOfMemory(char const*) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  6: 0x10030c6a4 v8::internal::Heap::RecomputeLimits(v8::internal::GarbageCollector) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  7: 0x10030943e v8::internal::Heap::PerformGarbageCollection(v8::internal::GarbageCollector, v8::GCCallbackFlags) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  8: 0x100307426 v8::internal::Heap::CollectGarbage(v8::internal::AllocationSpace, v8::internal::GarbageCollectionReason, v8::GCCallbackFlags) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  9: 0x100312daa v8::internal::Heap::AllocateRawWithLightRetrySlowPath(int, v8::internal::AllocationType, v8::internal::AllocationOrigin, v8::internal::AllocationAlignment) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 10: 0x100312e31 v8::internal::Heap::AllocateRawWithRetryOrFailSlowPath(int, v8::internal::AllocationType, v8::internal::AllocationOrigin, v8::internal::AllocationAlignment) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 11: 0x1002e0176 v8::internal::Factory::NewFillerObject(int, bool, v8::internal::AllocationType, v8::internal::AllocationOrigin) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 12: 0x100621338 v8::internal::Runtime_AllocateInYoungGeneration(int, unsigned long*, v8::internal::Isolate*) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 13: 0x100954639 Builtins_CEntry_Return1_DontSaveFPRegs_ArgvOnStack_NoBuiltinExit [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 13 / 1981 - contracts//0x79cd096f924d1db4ef02f3d56e8bb8946985cb1f_0.5.0
# 14 / 1981 - contracts//0x72c12145fcaef3ee74ba10497b81ef36f50bf6da_0.4.25
# [symEvm] info: Start Analyzing Contract: MigtyJackContract
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 2288
# [symEvm] info: |	cjumpis    : 54
# [symEvm] info: |	njumpis    : 54
# [symEvm] info: |	bytelen    : 2897
# [symEvm] info: |	concolic   : 673
# [symEvm] info: |	success    : [56870,76742,42291,1908]
# [symEvm] info: |	failed     : [0,1062,1062,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 88324
# [symEvm] info: |	scanner    : 32
# [symEvm] info: |	integer    : false
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : false
# [symEvm] info: |	reentrancy : false
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : false
# 15 / 1981 - contracts//0x27e627d032593fe2a8ebbb30f3b1264b3b51a707_0.5.8
# [symEvm] info: Start Analyzing Contract: PropertyCoin
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 130
# [symEvm] info: |	cjumpis    : 36
# [symEvm] info: |	njumpis    : 36
# [symEvm] info: |	bytelen    : 4809
# [symEvm] info: |	concolic   : 26
# [symEvm] info: |	success    : [92,2471,1748,16]
# [symEvm] info: |	failed     : [0,46,46,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 3264
# [symEvm] info: |	scanner    : 22
# [symEvm] info: |	integer    : false
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : false
# [symEvm] info: |	reentrancy : false
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : false
# 16 / 1981 - contracts//0xdff7e41173ca9c79db3dea3711875e6b974db4c0_0.5.8
# [symEvm] info: Start Analyzing Contract: Token
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 1145
# [symEvm] info: |	cjumpis    : 66
# [symEvm] info: |	njumpis    : 66
# [symEvm] info: |	bytelen    : 7367
# [symEvm] info: |	concolic   : 192
# [symEvm] info: |	success    : [22741,23009,19338,137]
# [symEvm] info: |	failed     : [0,486,486,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 30723
# assert.js:386
#     throw err;
#     ^
#
# AssertionError [ERR_ASSERTION]: The expression evaluated to a falsy value:
#
#   assert(block.name == 'Block')
#
#     at findFunctions (/Users/wuco/Projects/symEvm/src/shared/searching.js:112:5)
#     at Reentrancy.scan (/Users/wuco/Projects/symEvm/src/vul/reentrancy/index.js:88:10)
#     at Scanner.scan (/Users/wuco/Projects/symEvm/src/vul/index.js:32:26)
#     at /Users/wuco/Projects/symEvm/test/index.js:70:35
#     at /Users/wuco/Projects/symEvm/node_modules/lodash/lodash.js:4905:15
#     at baseForOwn (/Users/wuco/Projects/symEvm/node_modules/lodash/lodash.js:2990:24)
#     at /Users/wuco/Projects/symEvm/node_modules/lodash/lodash.js:4874:18
#     at forEach (/Users/wuco/Projects/symEvm/node_modules/lodash/lodash.js:9342:14)
#     at Object.<anonymous> (/Users/wuco/Projects/symEvm/test/index.js:32:1)
#     at Module._compile (internal/modules/cjs/loader.js:1151:30) {
#   generatedMessage: true,
#   code: 'ERR_ASSERTION',
#   actual: false,
#   expected: true,
#   operator: '=='
# }
# 17 / 1981 - contracts//0x551299d87bc2ccf8ed9272fd746212a504c66fdf_0.5.0
# 18 / 1981 - contracts//0x5695e8dc6f08855049ac3ec5f3d0b46ffde5271a_0.5.0
# [symEvm] info: Start Analyzing Contract: ProxyAdmin
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 148
# [symEvm] info: |	cjumpis    : 47
# [symEvm] info: |	njumpis    : 47
# [symEvm] info: |	bytelen    : 2904
# [symEvm] info: |	concolic   : 23
# [symEvm] info: |	success    : [119,2272,1850,2]
# [symEvm] info: |	failed     : [0,51,51,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 3963
# [symEvm] info: |	scanner    : 4650
# [symEvm] info: |	integer    : false
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : false
# [symEvm] info: |	reentrancy : false
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : false
# 19 / 1981 - contracts//0x7e4341ccd1d375433da8fd5d0cc19c51aeeb35f2_0.4.20
# [symEvm] info: Start Analyzing Contract: MultiSigWalletWithDailyLimit
#
# <--- Last few GCs --->
#
# [28966:0x1042d4000]    17561 ms: Mark-sweep 2047.1 (2050.9) -> 2046.8 (2050.7) MB, 1221.3 / 0.0 ms  (+ 478.0 ms in 97 steps since start of marking, biggest step 6.9 ms, walltime since start of marking 1737 ms) (average mu = 0.091, current mu = 0.029) allo[28966:0x1042d4000]    19121 ms: Mark-sweep 2047.3 (2050.7) -> 2046.7 (2050.9) MB, 1538.3 / 0.0 ms  (+ 21.2 ms in 4 steps since start of marking, biggest step 7.1 ms, walltime since start of marking 1560 ms) (average mu = 0.047, current mu = 0.001) alloca
#
# <--- JS stacktrace --->
#
# ==== JS stack trace =========================================
#
#     0: ExitFrame [pc: 0x100954639]
#     1: StubFrame [pc: 0x100907a9f]
#     2: StubFrame [pc: 0x10091f857]
# Security context: 0x175f7a140921 <JSObject>
#     3: execute [0x175f6135acc1] [/Users/wuco/Projects/symEvm/src/evm/evm.js:~60] [pc=0x23655d985743](this=0x175f99cf4d89 <Evm map = 0x175f6a8bcdf1>,5052,0x175f9709f259 <Ep map = 0x175f6a8bdf71>)
#     4: execute [0x175f6135acc1] [/Users/wuco/Projects/symEvm/src/evm/evm.js:~60] [pc=0x23655d98dc6...
#
# FATAL ERROR: Ineffective mark-compacts near heap limit Allocation failed - JavaScript heap out of memory
#
# Writing Node.js report to file: report.20200426.183309.28966.0.001.json
# Node.js report completed
#  1: 0x100082360 node::Abort() [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  2: 0x1000824e4 node::errors::TryCatchScope::~TryCatchScope() [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  3: 0x100182ba7 v8::Utils::ReportOOMFailure(v8::internal::Isolate*, char const*, bool) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  4: 0x100182b43 v8::internal::V8::FatalProcessOutOfMemory(v8::internal::Isolate*, char const*, bool) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  5: 0x10030afc5 v8::internal::Heap::FatalProcessOutOfMemory(char const*) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  6: 0x10030c6a4 v8::internal::Heap::RecomputeLimits(v8::internal::GarbageCollector) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  7: 0x10030943e v8::internal::Heap::PerformGarbageCollection(v8::internal::GarbageCollector, v8::GCCallbackFlags) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  8: 0x100307426 v8::internal::Heap::CollectGarbage(v8::internal::AllocationSpace, v8::internal::GarbageCollectionReason, v8::GCCallbackFlags) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  9: 0x100312daa v8::internal::Heap::AllocateRawWithLightRetrySlowPath(int, v8::internal::AllocationType, v8::internal::AllocationOrigin, v8::internal::AllocationAlignment) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 10: 0x100312e31 v8::internal::Heap::AllocateRawWithRetryOrFailSlowPath(int, v8::internal::AllocationType, v8::internal::AllocationOrigin, v8::internal::AllocationAlignment) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 11: 0x1002e0176 v8::internal::Factory::NewFillerObject(int, bool, v8::internal::AllocationType, v8::internal::AllocationOrigin) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 12: 0x100621338 v8::internal::Runtime_AllocateInYoungGeneration(int, unsigned long*, v8::internal::Isolate*) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 13: 0x100954639 Builtins_CEntry_Return1_DontSaveFPRegs_ArgvOnStack_NoBuiltinExit [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 14: 0x100907a9f Builtins_CloneFastJSArrayFillingHoles [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 15: 0x10091f857 Builtins_IterableToListWithSymbolLookup [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 20 / 1981 - contracts//0x2c7432d92070ba9ee34141e7a750bd577c239049_0.5.15
# [symEvm] info: Start Analyzing Contract: ERC20Token
# [symEvm] info: update maxVisitedBlock to 40
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 4690
# [symEvm] info: |	cjumpis    : 150
# [symEvm] info: |	njumpis    : 150
# [symEvm] info: |	bytelen    : 13771
# [symEvm] info: |	concolic   : 826
# 21 / 1981 - contracts//0x7f130471f1e358e4653a995184e77295093cc804_0.4.21
# [symEvm] info: Start Analyzing Contract: MyToken
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 1103
# [symEvm] info: |	cjumpis    : 42
# [symEvm] info: |	njumpis    : 42
# [symEvm] info: |	bytelen    : 3487
# [symEvm] info: |	concolic   : 181
# [symEvm] info: |	success    : [26224,26934,20831,18]
# [symEvm] info: |	failed     : [0,554,554,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 40715
# 22 / 1981 - contracts//0x710b724c91ee8d02ae6ce7122844613dc2b2da9d_0.4.24
# [symEvm] info: Start Analyzing Contract: Main0034_feeaccount_transfer
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 15
# [symEvm] info: |	cjumpis    : 14
# [symEvm] info: |	njumpis    : 14
# [symEvm] info: |	bytelen    : 1221
# [symEvm] info: |	concolic   : 4
# [symEvm] info: |	success    : [0,0,46,0]
# [symEvm] info: |	failed     : [0,0,0,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 43
# [symEvm] info: |	scanner    : 130
# [symEvm] info: |	integer    : false
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : false
# [symEvm] info: |	reentrancy : false
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : false
# 23 / 1981 - contracts//0x0aa8fa3b0b1deb46488250a1755ba58905f99de2_0.5.0
# [symEvm] info: Start Analyzing Contract: ProxyAdmin
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 148
# [symEvm] info: |	cjumpis    : 47
# [symEvm] info: |	njumpis    : 47
# [symEvm] info: |	bytelen    : 2904
# [symEvm] info: |	concolic   : 22
# [symEvm] info: |	success    : [119,2272,1850,2]
# [symEvm] info: |	failed     : [0,51,51,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 4186
# [symEvm] info: |	scanner    : 4456
# [symEvm] info: |	integer    : false
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : false
# [symEvm] info: |	reentrancy : false
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : false
# 24 / 1981 - contracts//0xc1a48363ed71a9fd2967b967b89e9458a30cb554_0.5.0
# [symEvm] info: Start Analyzing Contract: AdminUpgradeabilityProxy
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 42
# [symEvm] info: |	cjumpis    : 27
# [symEvm] info: |	njumpis    : 27
# [symEvm] info: |	bytelen    : 2270
# [symEvm] info: |	concolic   : 11
# [symEvm] info: |	success    : [78,0,134,6]
# [symEvm] info: |	failed     : [0,0,0,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 90
# [symEvm] info: |	scanner    : 310
# [symEvm] info: |	integer    : false
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : false
# [symEvm] info: |	reentrancy : false
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : true
# 25 / 1981 - contracts//0xd7a94d2f57948db1a9ce3b315282d3cf25c303aa_0.4.23
# [symEvm] info: Start Analyzing Contract: DubaiRealEstate
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 210
# [symEvm] info: |	cjumpis    : 90
# [symEvm] info: |	njumpis    : 94
# [symEvm] info: |	bytelen    : 8139
# [symEvm] info: |	concolic   : 37
# [symEvm] info: |	success    : [608,2645,1918,27]
# [symEvm] info: |	failed     : [0,48,48,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 4682
# [symEvm] info: |	scanner    : 1533
# [symEvm] info: |	integer    : true
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : false
# [symEvm] info: |	reentrancy : false
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : false
# 26 / 1981 - contracts//0xa6cde40d861c902fb1a92d9b9c00d04dfb540e39_0.5.15
# [symEvm] info: Start Analyzing Contract: ERC20Token
# [symEvm] info: update maxVisitedBlock to 40
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 4690
# [symEvm] info: |	cjumpis    : 150
# [symEvm] info: |	njumpis    : 150
# [symEvm] info: |	bytelen    : 13771
# [symEvm] info: |	concolic   : 745
# 27 / 1981 - contracts//0x150c7856bea3b6cdcac0013dc3d6fa50fffaa35d_0.5.11
# /Users/wuco/Projects/symEvm/test/index.js:40
#   const auxdata = contractJson['asm']['.data'][0]['.auxdata']
#                                      ^
#
# TypeError: Cannot read property '.data' of null
#     at /Users/wuco/Projects/symEvm/test/index.js:40:38
#     at /Users/wuco/Projects/symEvm/node_modules/lodash/lodash.js:4905:15
#     at baseForOwn (/Users/wuco/Projects/symEvm/node_modules/lodash/lodash.js:2990:24)
#     at /Users/wuco/Projects/symEvm/node_modules/lodash/lodash.js:4874:18
#     at forEach (/Users/wuco/Projects/symEvm/node_modules/lodash/lodash.js:9342:14)
#     at Object.<anonymous> (/Users/wuco/Projects/symEvm/test/index.js:32:1)
#     at Module._compile (internal/modules/cjs/loader.js:1151:30)
#     at Object.Module._extensions..js (internal/modules/cjs/loader.js:1171:10)
#     at Module.load (internal/modules/cjs/loader.js:1000:32)
#     at Function.Module._load (internal/modules/cjs/loader.js:899:14)
# 28 / 1981 - contracts//0x1c09ef4493465569f6d704a5cc4f9864bcd2e56a_0.5.15
# [symEvm] info: Start Analyzing Contract: ERC20Token
# [symEvm] info: update maxVisitedBlock to 40
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 4690
# [symEvm] info: |	cjumpis    : 150
# [symEvm] info: |	njumpis    : 150
# [symEvm] info: |	bytelen    : 13771
# [symEvm] info: |	concolic   : 757
# 29 / 1981 - contracts//0x75adaf5be177642c73d5490c9a2ef96e250d4ccf_0.5.15
# [symEvm] info: Start Analyzing Contract: ERC20Token
# [symEvm] info: update maxVisitedBlock to 40
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 4690
# [symEvm] info: |	cjumpis    : 150
# [symEvm] info: |	njumpis    : 150
# [symEvm] info: |	bytelen    : 13771
# [symEvm] info: |	concolic   : 854
# 30 / 1981 - contracts//0x82533f08ed23640bcce12542ac624e71da000b37_0.4.20
# [symEvm] info: Start Analyzing Contract: MultiSigWalletWithDailyLimit
#
# <--- Last few GCs --->
#
# [29031:0x1042d4000]    16960 ms: Scavenge 2046.1 (2050.9) -> 2045.6 (2053.7) MB, 2.7 / 0.0 ms  (average mu = 0.120, current mu = 0.067) allocation failure
# [29031:0x1042d4000]    18048 ms: Mark-sweep 2047.7 (2053.7) -> 2047.2 (2051.7) MB, 943.2 / 0.0 ms  (+ 142.6 ms in 32 steps since start of marking, biggest step 6.3 ms, walltime since start of marking 1088 ms) (average mu = 0.079, current mu = 0.011) alloc
#
# <--- JS stacktrace --->
#
# ==== JS stack trace =========================================
#
#     0: ExitFrame [pc: 0x100954639]
#     1: StubFrame [pc: 0x10090811d]
# Security context: 0x1c4244980921 <JSObject>
#     2: splice [0x1c424499a369](this=0x1c42e6082811 <JSArray[12]>,-2)
#     3: popN [0x1c420a8b7e01] [/Users/wuco/Projects/symEvm/src/evm/stack.js:~23] [pc=0x3836a74e974b](this=0x1c42e60827f1 <Stack map = 0x1c42bf0bdcf1>,2)
#     4: execute [0x1c42ca2141f9] [/Users/wuco/Projects/symEvm/src/evm/evm.js:~60] [pc=0x3836a74c73f7](this=0...
#
# FATAL ERROR: Ineffective mark-compacts near heap limit Allocation failed - JavaScript heap out of memory
#
# Writing Node.js report to file: report.20200426.184346.29031.0.001.json
# Node.js report completed
#  1: 0x100082360 node::Abort() [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  2: 0x1000824e4 node::errors::TryCatchScope::~TryCatchScope() [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  3: 0x100182ba7 v8::Utils::ReportOOMFailure(v8::internal::Isolate*, char const*, bool) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  4: 0x100182b43 v8::internal::V8::FatalProcessOutOfMemory(v8::internal::Isolate*, char const*, bool) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  5: 0x10030afc5 v8::internal::Heap::FatalProcessOutOfMemory(char const*) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  6: 0x10030c6a4 v8::internal::Heap::RecomputeLimits(v8::internal::GarbageCollector) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  7: 0x10030943e v8::internal::Heap::PerformGarbageCollection(v8::internal::GarbageCollector, v8::GCCallbackFlags) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  8: 0x100307426 v8::internal::Heap::CollectGarbage(v8::internal::AllocationSpace, v8::internal::GarbageCollectionReason, v8::GCCallbackFlags) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  9: 0x100312daa v8::internal::Heap::AllocateRawWithLightRetrySlowPath(int, v8::internal::AllocationType, v8::internal::AllocationOrigin, v8::internal::AllocationAlignment) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 10: 0x100312e31 v8::internal::Heap::AllocateRawWithRetryOrFailSlowPath(int, v8::internal::AllocationType, v8::internal::AllocationOrigin, v8::internal::AllocationAlignment) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 11: 0x1002e0176 v8::internal::Factory::NewFillerObject(int, bool, v8::internal::AllocationType, v8::internal::AllocationOrigin) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 12: 0x100621338 v8::internal::Runtime_AllocateInYoungGeneration(int, unsigned long*, v8::internal::Isolate*) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 13: 0x100954639 Builtins_CEntry_Return1_DontSaveFPRegs_ArgvOnStack_NoBuiltinExit [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 31 / 1981 - contracts//0x6718714a6af74e92425bce8b02fffb754d3a4cf0_0.5.15
# [symEvm] info: Start Analyzing Contract: ERC20Token
# [symEvm] info: update maxVisitedBlock to 40
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 4690
# [symEvm] info: |	cjumpis    : 150
# [symEvm] info: |	njumpis    : 150
# [symEvm] info: |	bytelen    : 13771
# [symEvm] info: |	concolic   : 795
# 32 / 1981 - contracts//0x3918cd48a9eeb0f7194a15f57be470a940bdcd0e_0.5.15
# [symEvm] info: Start Analyzing Contract: ERC20Token
# [symEvm] info: update maxVisitedBlock to 40
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 4690
# [symEvm] info: |	cjumpis    : 150
# [symEvm] info: |	njumpis    : 150
# [symEvm] info: |	bytelen    : 13771
# [symEvm] info: |	concolic   : 759
# 33 / 1981 - contracts//0x3cfe3cc00468a863c8661279feef9151ca216137_0.5.11
# 34 / 1981 - contracts//0x3318d98e4cff8ba162752de3d140640c72d462e9_0.5.16
# [symEvm] info: Start Analyzing Contract: SimpleGriefing_Factory
# [symEvm] info: update maxVisitedBlock to 40
# [symEvm] info: update maxVisitedBlock to 50
#
# <--- Last few GCs --->
#
# [29053:0x1042d4000]    24265 ms: Mark-sweep 2037.2 (2059.1) -> 2034.2 (2045.3) MB, 147.4 / 0.0 ms  (+ 723.6 ms in 169 steps since start of marking, biggest step 9.0 ms, walltime since start of marking 882 ms) (average mu = 0.086, current mu = 0.024) final[29053:0x1042d4000]    24274 ms: Scavenge 2041.1 (2045.3) -> 2030.4 (2064.8) MB, 6.3 / 0.0 ms  (average mu = 0.086, current mu = 0.024) allocation failure
#
#
# <--- JS stacktrace --->
#
# ==== JS stack trace =========================================
#
#     0: ExitFrame [pc: 0x100954639]
# Security context: 0x228f8d000921 <JSObject>
#     1: execute [0x228f7f0a0251] [/Users/wuco/Projects/symEvm/src/evm/evm.js:~60] [pc=0x1dcb90a71728](this=0x228fb9ad0a21 <Evm map = 0x228f9ed7efb1>,4319,0x228f0e78d479 <Ep map = 0x228f23080261>)
#     2: execute [0x228f7f0a0251] [/Users/wuco/Projects/symEvm/src/evm/evm.js:~60] [pc=0x1dcb90a70dae](this=0x228fb9ad0a21 <Evm map = 0x228f9ed7efb1>,4804,0x228f0e7836c1 ...
#
# FATAL ERROR: Ineffective mark-compacts near heap limit Allocation failed - JavaScript heap out of memory
#  1: 0x100082360 node::Abort() [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  2: 0x1000824e4 node::errors::TryCatchScope::~TryCatchScope() [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  3: 0x100182ba7 v8::Utils::ReportOOMFailure(v8::internal::Isolate*, char const*, bool) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  4: 0x100182b43 v8::internal::V8::FatalProcessOutOfMemory(v8::internal::Isolate*, char const*, bool) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  5: 0x10030afc5 v8::internal::Heap::FatalProcessOutOfMemory(char const*) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  6: 0x10030c6a4 v8::internal::Heap::RecomputeLimits(v8::internal::GarbageCollector) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  7: 0x10030943e v8::internal::Heap::PerformGarbageCollection(v8::internal::GarbageCollector, v8::GCCallbackFlags) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  8: 0x100307426 v8::internal::Heap::CollectGarbage(v8::internal::AllocationSpace, v8::internal::GarbageCollectionReason, v8::GCCallbackFlags) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
#  9: 0x1003062d1 v8::internal::Heap::HandleGCRequest() [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 10: 0x1002cae40 v8::internal::StackGuard::HandleInterrupts() [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 11: 0x100620a29 v8::internal::Runtime_StackGuard(int, unsigned long*, v8::internal::Isolate*) [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 12: 0x100954639 Builtins_CEntry_Return1_DontSaveFPRegs_ArgvOnStack_NoBuiltinExit [/Users/wuco/.nvm/versions/node/v13.8.0/bin/node]
# 13: 0x1dcb90a71728
# 14: 0x1dcb90a70dae
# 35 / 1981 - contracts//0x9f623e51165102c1b7febbbbc25b76c751633155_0.5.0
# [symEvm] info: Start Analyzing Contract: FixedSupplyToken
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 1227
# [symEvm] info: |	cjumpis    : 64
# [symEvm] info: |	njumpis    : 64
# [symEvm] info: |	bytelen    : 5497
# [symEvm] info: |	concolic   : 200
# [symEvm] info: |	success    : [26203,29852,23622,126]
# [symEvm] info: |	failed     : [0,611,611,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 48460
# [symEvm] info: |	scanner    : 6094
# [symEvm] info: |	integer    : false
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : false
# [symEvm] info: |	reentrancy : false
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : false
# 36 / 1981 - contracts//0x66f330546bf4c77e35a25f4a36410e507845f6b1_0.5.0
# [symEvm] info: Start Analyzing Contract: TokenMintERC20Token
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 1116
# [symEvm] info: |	cjumpis    : 50
# [symEvm] info: |	njumpis    : 50
# [symEvm] info: |	bytelen    : 4809
# [symEvm] info: |	concolic   : 177
# [symEvm] info: |	success    : [26217,26918,20886,19]
# [symEvm] info: |	failed     : [0,554,554,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 40914
# [symEvm] info: |	scanner    : 88
# [symEvm] info: |	integer    : false
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : true
# [symEvm] info: |	reentrancy : false
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : false
# 37 / 1981 - contracts//0x9d2ae6f194dc4c44b18d604efbbc0e90ad3eb5e0_0.5.15
# [symEvm] info: Start Analyzing Contract: ERC20Token
# [symEvm] info: update maxVisitedBlock to 40
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 4690
# [symEvm] info: |	cjumpis    : 150
# [symEvm] info: |	njumpis    : 150
# [symEvm] info: |	bytelen    : 13771
# [symEvm] info: |	concolic   : 766
# 38 / 1981 - contracts//0x3e3a219b53f47f5b50aea45828bac815796433b1_0.4.18
# 39 / 1981 - contracts//0x731bb2194de9d32ec15473ea3ab78e5f1cb4496f_0.6.0
# [symEvm] info: Start Analyzing Contract: Crowdsale
# [symEvm] info: ----------------------------------------------
# [symEvm] info: |	endpoints  : 41
# [symEvm] info: |	cjumpis    : 40
# [symEvm] info: |	njumpis    : 40
# [symEvm] info: |	bytelen    : 3697
# [symEvm] info: |	concolic   : 11
# [symEvm] info: |	success    : [49,0,109,4]
# [symEvm] info: |	failed     : [0,0,0,0]
# [symEvm] info: |	label      : [sloads,mloads,mstores,sstores]
# [symEvm] info: |	tainting   : 78
# [symEvm] info: |	scanner    : 289
# [symEvm] info: |	integer    : false
# [symEvm] info: |	disorder   : false
# [symEvm] info: |	frez       : false
# [symEvm] info: |	reentrancy : false
# [symEvm] info: |	timestamp  : false
# [symEvm] info: |	number     : false
# [symEvm] info: |	delegate   : false
# 40 / 1981 - contracts//0x355fd487888e2c1355ff46ddbff9b079a0351c10_0.4.20
# 41 / 1981 - contracts//0x734a48f1dafb36fa54af1a16573987b4ea6e3b83_0.5.15
